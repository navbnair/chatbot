# %% [markdown]
# <a href="https://colab.research.google.com/github/navbnair/chatbot/blob/main/PyTorch_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#used to avoid issues with string formats and output format
from __future__ import absolute_import
from __future__ import division 
from __future__ import print_function
from __future__ import unicode_literals

# %%
#implementing PyTorch module
import torch
from torch.jit import script,trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
import os
import re
import random
import csv
import unicodedata
import codecs
from io import open
import itertools
import math

USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %%
from glob import glob
corpus_loc = r"/content/drive/MyDrive/cornellmovie-dialogscorpus"
corpus = os.path.join("data", corpus_loc)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

# %%
#splits each line into a dictionary of fields
def loadLines(fileName, fields):
    lines = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            lineObj = {}
            for i, field in enumerate(fields):
                lineObj[field] = values[i]
            lines[lineObj['lineID']] = lineObj
    return lines


#group fields of lines based on conversations
def loadConversations(fileName, lines, fields):
    conversations = []
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            #extract necessary fields
            convObj = {}
            for i, field in enumerate(fields):
                convObj[field] = values[i]
            #convert string to list
            utterance_id_pattern = re.compile('L[0-9]+')
            lineIds = utterance_id_pattern.findall(convObj["utteranceIDs"])
            #reconstruct lines
            convObj["lines"] = []
            for lineId in lineIds:
                convObj["lines"].append(lines[lineId])
            conversations.append(convObj)
    return conversations


#extract relevant sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations:
        #iterate over all lines of conversation
        for i in range(len(conversation["lines"]) - 1):  #ignoring the last line
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            #filter out incorrect samples
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %%
#define new file path
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
#delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

#initialise lines dict, conversations list, field ids
lines = {}
conversations = []
MOVIE_LINES_FIELDS = ["lineID", "characterID", "movieID", "character", "text"]
MOVIE_CONVERSATIONS_FIELDS = ["character1ID", "character2ID", "movieID", "utteranceIDs"]

#load lines and process conversations
print("\nProcessing corpus...")
lines = loadLines(os.path.join(corpus, "movie_lines.txt"), MOVIE_LINES_FIELDS)
print("\nLoading conversations...")
conversations = loadConversations(os.path.join(corpus, "movie_conversations.txt"),
                                  lines, MOVIE_CONVERSATIONS_FIELDS)

#create new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

#print sample lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus...
#
# Loading conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b"Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.\tWell, I thought we'd start with pronunciation, if that's okay with you.\n"
# b"Well, I thought we'd start with pronunciation, if that's okay with you.\tNot the hacking and gagging and spitting part.  Please.\n"
# b"Not the hacking and gagging and spitting part.  Please.\tOkay... then how 'bout we try out some French cuisine.  Saturday?  Night?\n"
# b"You're asking me out.  That's so cute. What's your name again?\tForget it.\n"
# b"No, no, it's my fault -- we didn't have a proper introduction ---\tCameron.\n"
# b"Cameron.\tThe thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\n"
# b"The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\tSeems like she could get a date easy enough...\n"
# b'Why?\tUnsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\n'
# b"Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\tThat's a shame.\n"
# b'Gosh, if only we could find Kat a boyfriend...\tLet me see what I can do.\n'

# %%
PAD_token = 0 #pad short sentences
SOS_token = 1 #start-of-sentence token
EOS_token = 2 #end-of-sentence token

class Voc:
  def __init__(self, name):
    self.name = name
    self.trimmed = False
    self.word2index = {}
    self.word2count = {}
    self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
    self.num_words = 3

  def addSentence(self, sentence):
    for word in sentence.split(' '):
      self.addWord(word)

  def addWord(self, word):
    if word not in self.word2index:
      self.word2index[word] = self.num_words
      self.word2count[word] = 1
      self.index2word[self.num_words] = word
      self.num_words += 1
    else:
      self.word2count[word] += 1

  def trim(self, min_count):
    if self.trimmed:
      return
    self.trimmed = True

    keep_words = []

    for k, v in self.word2count.items():
      if v >= min_count:
        keep_words.append(k)

    print('keep_words {} / {} = {:.4f}'.format(
        len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
    ))

    self.word2index = {}
    self.word2count = {}
    self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
    self.num_words = 3

    for word in keep_words:
      self.addWord(word)

# %%
MAX_LENGTH = 10  #maximum sentence length considered

#convert Unicode string into ASCII
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

#convert to lowercase, trim and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

#read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    #read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    #splt lines into pairs and normalise
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

#returns true iff both sentences in a pair are under the MAX_LENGTH threshold
def filterPair(p):
    #input sequences to prreserve the last word for EOS Token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

#filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

#using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


#load/assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_loc, datafile, save_dir)
#print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64271 sentence pairs
# Counting words...
# Counted words: 18008
#
# pairs:
# ['there .', 'where ?']
# ['you have my word . as a gentleman', 'you re sweet .']
# ['hi .', 'looks like things worked out tonight huh ?']
# ['you know chastity ?', 'i believe we share an art instructor']
# ['have fun tonight ?', 'tons']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['what good stuff ?', 'the real you .']

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    #trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    #filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        #check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        #check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        #only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


#trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7823 / 18005 = 0.4345
# Trimmed from 64271 pairs to 53165, 0.8272 of total

# %%
def indexesFromSentence(voc, sentence):
  return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]

def zeroPadding(l, fillvalue=PAD_token):
  return list(itertools.zip_longest(*l, fillvalue = fillvalue))

def binaryMatrix(l, value = PAD_token):
  m = []
  for i,seq in enumerate(l):
    m.append([])
    for token in seq:
      if token == PAD_token:
        m[i].append(0)
      else:
        m[i].append(1)
  return m

def inputVar(l, voc):
  indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
  lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
  padList = zeroPadding(indexes_batch)
  padVar = torch.LongTensor(padList)
  return padVar, lengths

def outputVar(l, voc):
  indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
  max_target_len = max([len(indexes) for indexes in indexes_batch])
  padList = zeroPadding(indexes_batch)
  mask = binaryMatrix(padList)
  mask = torch.BoolTensor(mask)
  padVar = torch.LongTensor(padList)
  return padVar, mask, max_target_len

def batch2TrainData(voc, pair_batch):
  pair_batch.sort(key = lambda x: len(x[0].split(" ")), reverse=True)
  input_batch, output_batch = [], []
  for pair in pair_batch:
    input_batch.append(pair[0])
    output_batch.append(pair[1])
  inp, lengths = inputVar(input_batch, voc)
  output, mask, max_target_len = outputVar(output_batch, voc)
  return inp, lengths, output, mask, max_target_len

small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable: ", input_variable)
print("lengths: ", lengths)
print("target_variable: ", target_variable)
print("max_target_len: ", max_target_len)
# Out:
# input_variable:  tensor([[  64,   77, 1264, 5042, 5511],
#         [  95,  115,  158,   66, 5511],
#         [  65,   53,   12,   66,    4],
#         [  26,  859, 2582,    2,    2],
#         [  83,    4,   66,    0,    0],
#         [   4,    2,    2,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths:  tensor([7, 6, 6, 4, 4])
# target_variable:  tensor([[ 318,  232,  124, 5043,   50],
#         [  65,    4,    9,   66,  148],
#         [  26,    2,  125,   66,   65],
#         [   7,    0,  242,    2,  614],
#         [   4,    0,  188,    0,  170],
#         [   2,    0,  170,    0,   96],
#         [   0,    0,   66,    0, 3715],
#         [   0,    0,    2,    0,    6],
#         [   0,    0,    0,    0,    2]])
# max_target_len:  9

# %%
class EncoderRNN(nn.Module):
  def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
    super(EncoderRNN, self).__init__()
    self.n_layers = n_layers
    self.hidden_size = hidden_size
    self.embedding = embedding

    self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                      dropout = (0 if n_layers == 1 else dropout), bidirectional=True)
    
  def forward(self, input_seq, input_lengths, hidden=None):
    #convert word indexes to embedding
    embedded = self.embedding(input_seq)
    #pack padded batch of sequences for RNN module
    packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
    #forward pass through GRU
    outputs, hidden = self.gru(packed, hidden)
    #unpack padding
    outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
    #sum bidirectional GRU outputs
    outputs = outputs[:, :, :self.hidden_size] + outputs[:,:, self.hidden_size:]
    #return output and final hidden state
    return outputs, hidden

# %%
class Attn(nn.Module):
  def __init__(self, method, hidden_size):
    super(Attn, self).__init__()
    self.method = method
    if self.method not in ['dot', 'general', 'concat']:
      raise ValueError(self.method, "is not an appropriate attention method.")
    self.hidden_size = hidden_size
    if self.method == 'general':
      self.attn = nn.Linear(self.hidden_size, hidden_size)
    elif self.method == 'concat':
      self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
      self.v = nn.Parameter(torch.FloatTensor(hidden_size))

  def dot_score(self, hidden, encoder_output):
    return torch.sum(hidden * encoder_output, dim=2)

  def general_score(self, hidden, encoder_output):
    energy = self.attn(encoder_output)
    return torch.sum(hidden * energy, dim=2)

  def concat_score(self, hidden, encoder_output):
    energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
    return torch.sum(self.v * energy, dim = 2)

  def forward(self, hidden, encoder_outputs):

    if self.method == 'general':
      attn_energies = self.general_score(hidden, encoder_outputs)
    elif self.method == 'concat':
      attn_energies = self.concat_score(hidden, encoder_outputs)
    elif self.method == 'dot':
      attn_energies = self.dot_score(hidden, encoder_outputs)

      attn_energies = attn_energies.t()

      return F.softmax(attn_energies, dim = 1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
  def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers = 1, dropout = 0.1):
    super(LuongAttnDecoderRNN, self).__init__()

    self.attn_model = attn_model
    self.hidden_size = hidden_size
    self.output_size = output_size
    self.n_layers = n_layers
    self.dropout = dropout

    self.embedding = embedding
    self.embedding_dropout = nn.Dropout(dropout)
    self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
    self.concat = nn.Linear(hidden_size * 2, hidden_size)
    self.out = nn.Linear(hidden_size, output_size)

    self.attn = Attn(attn_model, hidden_size)

  def forward(self, input_step, last_hidden, encoder_outputs):
    embedded = self.embedding(input_step)
    embedded = self.embedding_dropout(embedded)

    rnn_output, hidden = self.gru(embedded, last_hidden)

    attn_weights = self.attn(rnn_output, encoder_outputs)

    context = attn_weights.bmm(encoder_outputs.transpose(0,1))

    rnn_output = rnn_output.squeeze(0)
    context = context.squeeze(1)
    concat_input = torch.cat((rnn_output, context), 1)
    concat_output = torch.tanh(self.concat(concat_input))

    output = self.out(concat_output)
    output = F.softmax(output, dim = 1)

    return output, hidden

# %%
def maskNLLLoss(inp, target, mask):
  nTotal = mask.sum()
  crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
  loss = crossEntropy.masked_select(mask).mean()
  loss = loss.to(device)
  return loss, nTotal.item()

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden, encoder_outputs)
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have cuda, configure cuda to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_loc, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9769
# Iteration: 2; Percent complete: 0.1%; Average loss: 8.8611
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.6826
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.4718
# Iteration: 5; Percent complete: 0.1%; Average loss: 8.1128
# Iteration: 6; Percent complete: 0.1%; Average loss: 7.6041
# Iteration: 7; Percent complete: 0.2%; Average loss: 7.1591
# Iteration: 8; Percent complete: 0.2%; Average loss: 7.0771
# Iteration: 9; Percent complete: 0.2%; Average loss: 7.0320
# Iteration: 10; Percent complete: 0.2%; Average loss: 6.7616
# Iteration: 11; Percent complete: 0.3%; Average loss: 6.3532
# Iteration: 12; Percent complete: 0.3%; Average loss: 5.9564
# Iteration: 13; Percent complete: 0.3%; Average loss: 5.5234
# Iteration: 14; Percent complete: 0.4%; Average loss: 5.7289
# Iteration: 15; Percent complete: 0.4%; Average loss: 5.5946
# Iteration: 16; Percent complete: 0.4%; Average loss: 5.3375
# Iteration: 17; Percent complete: 0.4%; Average loss: 5.1665
# Iteration: 18; Percent complete: 0.4%; Average loss: 5.2457
# Iteration: 19; Percent complete: 0.5%; Average loss: 5.0015
# Iteration: 20; Percent complete: 0.5%; Average loss: 4.9642
# Iteration: 21; Percent complete: 0.5%; Average loss: 5.2116
# Iteration: 22; Percent complete: 0.5%; Average loss: 4.8614
# Iteration: 23; Percent complete: 0.6%; Average loss: 5.1224
# Iteration: 24; Percent complete: 0.6%; Average loss: 4.9417
# Iteration: 25; Percent complete: 0.6%; Average loss: 4.8300
# Iteration: 26; Percent complete: 0.7%; Average loss: 4.9662
# Iteration: 27; Percent complete: 0.7%; Average loss: 4.8104
# Iteration: 28; Percent complete: 0.7%; Average loss: 4.7477
# Iteration: 29; Percent complete: 0.7%; Average loss: 4.6826
# Iteration: 30; Percent complete: 0.8%; Average loss: 4.5664
# Iteration: 31; Percent complete: 0.8%; Average loss: 4.5822
# Iteration: 32; Percent complete: 0.8%; Average loss: 4.7910
# Iteration: 33; Percent complete: 0.8%; Average loss: 4.6975
# Iteration: 34; Percent complete: 0.9%; Average loss: 4.9431
# Iteration: 35; Percent complete: 0.9%; Average loss: 4.3926
# Iteration: 36; Percent complete: 0.9%; Average loss: 4.9331
# Iteration: 37; Percent complete: 0.9%; Average loss: 4.5514
# Iteration: 38; Percent complete: 0.9%; Average loss: 4.6588
# Iteration: 39; Percent complete: 1.0%; Average loss: 4.7865
# Iteration: 40; Percent complete: 1.0%; Average loss: 4.6622
# Iteration: 41; Percent complete: 1.0%; Average loss: 4.6907
# Iteration: 42; Percent complete: 1.1%; Average loss: 5.0559
# Iteration: 43; Percent complete: 1.1%; Average loss: 4.7499
# Iteration: 44; Percent complete: 1.1%; Average loss: 4.8173
# Iteration: 45; Percent complete: 1.1%; Average loss: 4.7531
# Iteration: 46; Percent complete: 1.1%; Average loss: 4.5367
# Iteration: 47; Percent complete: 1.2%; Average loss: 4.6385
# Iteration: 48; Percent complete: 1.2%; Average loss: 4.5806
# Iteration: 49; Percent complete: 1.2%; Average loss: 4.7041
# Iteration: 50; Percent complete: 1.2%; Average loss: 4.8786
# Iteration: 51; Percent complete: 1.3%; Average loss: 4.7420
# Iteration: 52; Percent complete: 1.3%; Average loss: 4.5331
# Iteration: 53; Percent complete: 1.3%; Average loss: 4.6097
# Iteration: 54; Percent complete: 1.4%; Average loss: 4.6486
# Iteration: 55; Percent complete: 1.4%; Average loss: 4.5481
# Iteration: 56; Percent complete: 1.4%; Average loss: 4.8239
# Iteration: 57; Percent complete: 1.4%; Average loss: 4.5320
# Iteration: 58; Percent complete: 1.5%; Average loss: 4.6701
# Iteration: 59; Percent complete: 1.5%; Average loss: 4.3988
# Iteration: 60; Percent complete: 1.5%; Average loss: 4.6540
# Iteration: 61; Percent complete: 1.5%; Average loss: 4.4688
# Iteration: 62; Percent complete: 1.6%; Average loss: 4.4687
# Iteration: 63; Percent complete: 1.6%; Average loss: 4.4284
# Iteration: 64; Percent complete: 1.6%; Average loss: 4.6480
# Iteration: 65; Percent complete: 1.6%; Average loss: 4.7929
# Iteration: 66; Percent complete: 1.7%; Average loss: 4.4139
# Iteration: 67; Percent complete: 1.7%; Average loss: 4.2719
# Iteration: 68; Percent complete: 1.7%; Average loss: 4.4792
# Iteration: 69; Percent complete: 1.7%; Average loss: 4.3235
# Iteration: 70; Percent complete: 1.8%; Average loss: 4.4856
# Iteration: 71; Percent complete: 1.8%; Average loss: 4.3455
# Iteration: 72; Percent complete: 1.8%; Average loss: 4.5670
# Iteration: 73; Percent complete: 1.8%; Average loss: 4.4079
# Iteration: 74; Percent complete: 1.8%; Average loss: 4.3803
# Iteration: 75; Percent complete: 1.9%; Average loss: 4.5003
# Iteration: 76; Percent complete: 1.9%; Average loss: 4.6370
# Iteration: 77; Percent complete: 1.9%; Average loss: 4.3666
# Iteration: 78; Percent complete: 1.9%; Average loss: 4.3592
# Iteration: 79; Percent complete: 2.0%; Average loss: 4.2481
# Iteration: 80; Percent complete: 2.0%; Average loss: 4.4210
# Iteration: 81; Percent complete: 2.0%; Average loss: 4.6539
# Iteration: 82; Percent complete: 2.1%; Average loss: 4.6035
# Iteration: 83; Percent complete: 2.1%; Average loss: 4.6680
# Iteration: 84; Percent complete: 2.1%; Average loss: 4.6266
# Iteration: 85; Percent complete: 2.1%; Average loss: 4.5896
# Iteration: 86; Percent complete: 2.1%; Average loss: 4.4593
# Iteration: 87; Percent complete: 2.2%; Average loss: 4.4089
# Iteration: 88; Percent complete: 2.2%; Average loss: 4.5007
# Iteration: 89; Percent complete: 2.2%; Average loss: 4.3823
# Iteration: 90; Percent complete: 2.2%; Average loss: 4.5633
# Iteration: 91; Percent complete: 2.3%; Average loss: 4.6308
# Iteration: 92; Percent complete: 2.3%; Average loss: 4.4453
# Iteration: 93; Percent complete: 2.3%; Average loss: 4.5303
# Iteration: 94; Percent complete: 2.4%; Average loss: 4.3261
# Iteration: 95; Percent complete: 2.4%; Average loss: 4.4284
# Iteration: 96; Percent complete: 2.4%; Average loss: 4.2193
# Iteration: 97; Percent complete: 2.4%; Average loss: 4.5879
# Iteration: 98; Percent complete: 2.5%; Average loss: 4.1908
# Iteration: 99; Percent complete: 2.5%; Average loss: 4.5377
# Iteration: 100; Percent complete: 2.5%; Average loss: 4.2820
# Iteration: 101; Percent complete: 2.5%; Average loss: 4.5052
# Iteration: 102; Percent complete: 2.5%; Average loss: 4.4050
# Iteration: 103; Percent complete: 2.6%; Average loss: 4.4088
# Iteration: 104; Percent complete: 2.6%; Average loss: 4.2477
# Iteration: 105; Percent complete: 2.6%; Average loss: 4.3807
# Iteration: 106; Percent complete: 2.6%; Average loss: 4.3949
# Iteration: 107; Percent complete: 2.7%; Average loss: 4.2337
# Iteration: 108; Percent complete: 2.7%; Average loss: 4.2822
# Iteration: 109; Percent complete: 2.7%; Average loss: 4.3578
# Iteration: 110; Percent complete: 2.8%; Average loss: 4.2882
# Iteration: 111; Percent complete: 2.8%; Average loss: 4.5427
# Iteration: 112; Percent complete: 2.8%; Average loss: 4.4191
# Iteration: 113; Percent complete: 2.8%; Average loss: 4.3000
# Iteration: 114; Percent complete: 2.9%; Average loss: 4.1156
# Iteration: 115; Percent complete: 2.9%; Average loss: 4.4822
# Iteration: 116; Percent complete: 2.9%; Average loss: 4.4334
# Iteration: 117; Percent complete: 2.9%; Average loss: 4.4087
# Iteration: 118; Percent complete: 2.9%; Average loss: 4.2289
# Iteration: 119; Percent complete: 3.0%; Average loss: 4.3002
# Iteration: 120; Percent complete: 3.0%; Average loss: 4.0274
# Iteration: 121; Percent complete: 3.0%; Average loss: 4.0192
# Iteration: 122; Percent complete: 3.0%; Average loss: 4.4251
# Iteration: 123; Percent complete: 3.1%; Average loss: 4.2441
# Iteration: 124; Percent complete: 3.1%; Average loss: 3.9416
# Iteration: 125; Percent complete: 3.1%; Average loss: 4.1648
# Iteration: 126; Percent complete: 3.1%; Average loss: 4.4447
# Iteration: 127; Percent complete: 3.2%; Average loss: 4.3110
# Iteration: 128; Percent complete: 3.2%; Average loss: 4.4419
# Iteration: 129; Percent complete: 3.2%; Average loss: 4.4589
# Iteration: 130; Percent complete: 3.2%; Average loss: 4.2931
# Iteration: 131; Percent complete: 3.3%; Average loss: 4.5390
# Iteration: 132; Percent complete: 3.3%; Average loss: 4.3123
# Iteration: 133; Percent complete: 3.3%; Average loss: 4.2956
# Iteration: 134; Percent complete: 3.4%; Average loss: 4.2783
# Iteration: 135; Percent complete: 3.4%; Average loss: 4.3877
# Iteration: 136; Percent complete: 3.4%; Average loss: 4.2753
# Iteration: 137; Percent complete: 3.4%; Average loss: 4.3249
# Iteration: 138; Percent complete: 3.5%; Average loss: 4.2371
# Iteration: 139; Percent complete: 3.5%; Average loss: 4.0870
# Iteration: 140; Percent complete: 3.5%; Average loss: 4.3133
# Iteration: 141; Percent complete: 3.5%; Average loss: 4.4834
# Iteration: 142; Percent complete: 3.5%; Average loss: 4.3856
# Iteration: 143; Percent complete: 3.6%; Average loss: 4.1494
# Iteration: 144; Percent complete: 3.6%; Average loss: 4.4113
# Iteration: 145; Percent complete: 3.6%; Average loss: 4.2631
# Iteration: 146; Percent complete: 3.6%; Average loss: 3.9932
# Iteration: 147; Percent complete: 3.7%; Average loss: 4.5179
# Iteration: 148; Percent complete: 3.7%; Average loss: 4.3962
# Iteration: 149; Percent complete: 3.7%; Average loss: 4.2204
# Iteration: 150; Percent complete: 3.8%; Average loss: 4.1474
# Iteration: 151; Percent complete: 3.8%; Average loss: 4.1573
# Iteration: 152; Percent complete: 3.8%; Average loss: 4.2302
# Iteration: 153; Percent complete: 3.8%; Average loss: 4.1328
# Iteration: 154; Percent complete: 3.9%; Average loss: 4.3499
# Iteration: 155; Percent complete: 3.9%; Average loss: 4.4066
# Iteration: 156; Percent complete: 3.9%; Average loss: 4.2199
# Iteration: 157; Percent complete: 3.9%; Average loss: 3.8843
# Iteration: 158; Percent complete: 4.0%; Average loss: 4.2054
# Iteration: 159; Percent complete: 4.0%; Average loss: 4.0717
# Iteration: 160; Percent complete: 4.0%; Average loss: 4.3530
# Iteration: 161; Percent complete: 4.0%; Average loss: 4.1248
# Iteration: 162; Percent complete: 4.0%; Average loss: 4.0302
# Iteration: 163; Percent complete: 4.1%; Average loss: 4.3452
# Iteration: 164; Percent complete: 4.1%; Average loss: 4.1820
# Iteration: 165; Percent complete: 4.1%; Average loss: 4.4936
# Iteration: 166; Percent complete: 4.2%; Average loss: 4.3101
# Iteration: 167; Percent complete: 4.2%; Average loss: 4.0833
# Iteration: 168; Percent complete: 4.2%; Average loss: 4.2707
# Iteration: 169; Percent complete: 4.2%; Average loss: 4.1963
# Iteration: 170; Percent complete: 4.2%; Average loss: 4.2733
# Iteration: 171; Percent complete: 4.3%; Average loss: 4.0021
# Iteration: 172; Percent complete: 4.3%; Average loss: 4.3398
# Iteration: 173; Percent complete: 4.3%; Average loss: 3.9887
# Iteration: 174; Percent complete: 4.3%; Average loss: 4.3685
# Iteration: 175; Percent complete: 4.4%; Average loss: 3.8951
# Iteration: 176; Percent complete: 4.4%; Average loss: 4.0965
# Iteration: 177; Percent complete: 4.4%; Average loss: 4.0301
# Iteration: 178; Percent complete: 4.5%; Average loss: 4.3307
# Iteration: 179; Percent complete: 4.5%; Average loss: 4.2130
# Iteration: 180; Percent complete: 4.5%; Average loss: 4.1513
# Iteration: 181; Percent complete: 4.5%; Average loss: 4.2771
# Iteration: 182; Percent complete: 4.5%; Average loss: 3.9656
# Iteration: 183; Percent complete: 4.6%; Average loss: 4.0485
# Iteration: 184; Percent complete: 4.6%; Average loss: 4.1263
# Iteration: 185; Percent complete: 4.6%; Average loss: 4.1352
# Iteration: 186; Percent complete: 4.7%; Average loss: 4.0762
# Iteration: 187; Percent complete: 4.7%; Average loss: 4.2866
# Iteration: 188; Percent complete: 4.7%; Average loss: 4.1560
# Iteration: 189; Percent complete: 4.7%; Average loss: 4.1918
# Iteration: 190; Percent complete: 4.8%; Average loss: 4.0255
# Iteration: 191; Percent complete: 4.8%; Average loss: 4.1085
# Iteration: 192; Percent complete: 4.8%; Average loss: 4.1339
# Iteration: 193; Percent complete: 4.8%; Average loss: 4.2977
# Iteration: 194; Percent complete: 4.9%; Average loss: 4.1529
# Iteration: 195; Percent complete: 4.9%; Average loss: 4.1483
# Iteration: 196; Percent complete: 4.9%; Average loss: 3.8242
# Iteration: 197; Percent complete: 4.9%; Average loss: 4.1360
# Iteration: 198; Percent complete: 5.0%; Average loss: 4.0247
# Iteration: 199; Percent complete: 5.0%; Average loss: 4.1710
# Iteration: 200; Percent complete: 5.0%; Average loss: 3.8857
# Iteration: 201; Percent complete: 5.0%; Average loss: 4.1361
# Iteration: 202; Percent complete: 5.1%; Average loss: 4.2062
# Iteration: 203; Percent complete: 5.1%; Average loss: 4.1151
# Iteration: 204; Percent complete: 5.1%; Average loss: 4.0994
# Iteration: 205; Percent complete: 5.1%; Average loss: 4.1967
# Iteration: 206; Percent complete: 5.1%; Average loss: 4.0850
# Iteration: 207; Percent complete: 5.2%; Average loss: 4.1602
# Iteration: 208; Percent complete: 5.2%; Average loss: 4.1824
# Iteration: 209; Percent complete: 5.2%; Average loss: 4.1688
# Iteration: 210; Percent complete: 5.2%; Average loss: 4.3003
# Iteration: 211; Percent complete: 5.3%; Average loss: 3.9975
# Iteration: 212; Percent complete: 5.3%; Average loss: 3.9559
# Iteration: 213; Percent complete: 5.3%; Average loss: 4.1861
# Iteration: 214; Percent complete: 5.3%; Average loss: 3.7966
# Iteration: 215; Percent complete: 5.4%; Average loss: 4.0046
# Iteration: 216; Percent complete: 5.4%; Average loss: 4.3436
# Iteration: 217; Percent complete: 5.4%; Average loss: 4.0241
# Iteration: 218; Percent complete: 5.5%; Average loss: 4.0325
# Iteration: 219; Percent complete: 5.5%; Average loss: 4.1371
# Iteration: 220; Percent complete: 5.5%; Average loss: 4.1129
# Iteration: 221; Percent complete: 5.5%; Average loss: 4.3649
# Iteration: 222; Percent complete: 5.5%; Average loss: 4.1024
# Iteration: 223; Percent complete: 5.6%; Average loss: 4.3259
# Iteration: 224; Percent complete: 5.6%; Average loss: 4.0802
# Iteration: 225; Percent complete: 5.6%; Average loss: 4.1615
# Iteration: 226; Percent complete: 5.7%; Average loss: 4.0271
# Iteration: 227; Percent complete: 5.7%; Average loss: 3.8655
# Iteration: 228; Percent complete: 5.7%; Average loss: 4.1133
# Iteration: 229; Percent complete: 5.7%; Average loss: 3.9538
# Iteration: 230; Percent complete: 5.8%; Average loss: 4.1634
# Iteration: 231; Percent complete: 5.8%; Average loss: 3.7528
# Iteration: 232; Percent complete: 5.8%; Average loss: 3.7011
# Iteration: 233; Percent complete: 5.8%; Average loss: 3.9598
# Iteration: 234; Percent complete: 5.9%; Average loss: 3.8912
# Iteration: 235; Percent complete: 5.9%; Average loss: 4.3426
# Iteration: 236; Percent complete: 5.9%; Average loss: 4.1264
# Iteration: 237; Percent complete: 5.9%; Average loss: 3.9603
# Iteration: 238; Percent complete: 5.9%; Average loss: 3.9254
# Iteration: 239; Percent complete: 6.0%; Average loss: 4.1780
# Iteration: 240; Percent complete: 6.0%; Average loss: 3.9961
# Iteration: 241; Percent complete: 6.0%; Average loss: 4.2332
# Iteration: 242; Percent complete: 6.0%; Average loss: 3.7950
# Iteration: 243; Percent complete: 6.1%; Average loss: 4.1370
# Iteration: 244; Percent complete: 6.1%; Average loss: 3.8043
# Iteration: 245; Percent complete: 6.1%; Average loss: 3.9686
# Iteration: 246; Percent complete: 6.2%; Average loss: 4.0917
# Iteration: 247; Percent complete: 6.2%; Average loss: 4.1278
# Iteration: 248; Percent complete: 6.2%; Average loss: 3.8597
# Iteration: 249; Percent complete: 6.2%; Average loss: 3.9557
# Iteration: 250; Percent complete: 6.2%; Average loss: 4.0382
# Iteration: 251; Percent complete: 6.3%; Average loss: 3.7035
# Iteration: 252; Percent complete: 6.3%; Average loss: 3.8301
# Iteration: 253; Percent complete: 6.3%; Average loss: 3.8582
# Iteration: 254; Percent complete: 6.3%; Average loss: 3.9347
# Iteration: 255; Percent complete: 6.4%; Average loss: 3.9009
# Iteration: 256; Percent complete: 6.4%; Average loss: 3.7991
# Iteration: 257; Percent complete: 6.4%; Average loss: 3.8847
# Iteration: 258; Percent complete: 6.5%; Average loss: 4.1683
# Iteration: 259; Percent complete: 6.5%; Average loss: 4.1666
# Iteration: 260; Percent complete: 6.5%; Average loss: 3.7130
# Iteration: 261; Percent complete: 6.5%; Average loss: 3.7105
# Iteration: 262; Percent complete: 6.6%; Average loss: 3.7562
# Iteration: 263; Percent complete: 6.6%; Average loss: 3.9969
# Iteration: 264; Percent complete: 6.6%; Average loss: 3.7983
# Iteration: 265; Percent complete: 6.6%; Average loss: 4.2220
# Iteration: 266; Percent complete: 6.7%; Average loss: 3.7078
# Iteration: 267; Percent complete: 6.7%; Average loss: 3.8846
# Iteration: 268; Percent complete: 6.7%; Average loss: 3.8520
# Iteration: 269; Percent complete: 6.7%; Average loss: 3.8738
# Iteration: 270; Percent complete: 6.8%; Average loss: 4.0096
# Iteration: 271; Percent complete: 6.8%; Average loss: 4.2683
# Iteration: 272; Percent complete: 6.8%; Average loss: 3.8505
# Iteration: 273; Percent complete: 6.8%; Average loss: 3.9250
# Iteration: 274; Percent complete: 6.9%; Average loss: 3.8210
# Iteration: 275; Percent complete: 6.9%; Average loss: 3.8175
# Iteration: 276; Percent complete: 6.9%; Average loss: 3.9117
# Iteration: 277; Percent complete: 6.9%; Average loss: 3.9255
# Iteration: 278; Percent complete: 7.0%; Average loss: 3.9982
# Iteration: 279; Percent complete: 7.0%; Average loss: 3.7940
# Iteration: 280; Percent complete: 7.0%; Average loss: 3.9050
# Iteration: 281; Percent complete: 7.0%; Average loss: 3.8868
# Iteration: 282; Percent complete: 7.0%; Average loss: 4.0236
# Iteration: 283; Percent complete: 7.1%; Average loss: 4.0512
# Iteration: 284; Percent complete: 7.1%; Average loss: 3.7309
# Iteration: 285; Percent complete: 7.1%; Average loss: 3.8359
# Iteration: 286; Percent complete: 7.1%; Average loss: 3.8704
# Iteration: 287; Percent complete: 7.2%; Average loss: 3.9272
# Iteration: 288; Percent complete: 7.2%; Average loss: 3.9682
# Iteration: 289; Percent complete: 7.2%; Average loss: 3.9481
# Iteration: 290; Percent complete: 7.2%; Average loss: 3.7809
# Iteration: 291; Percent complete: 7.3%; Average loss: 4.1593
# Iteration: 292; Percent complete: 7.3%; Average loss: 3.8151
# Iteration: 293; Percent complete: 7.3%; Average loss: 4.1104
# Iteration: 294; Percent complete: 7.3%; Average loss: 3.9903
# Iteration: 295; Percent complete: 7.4%; Average loss: 3.7670
# Iteration: 296; Percent complete: 7.4%; Average loss: 3.9237
# Iteration: 297; Percent complete: 7.4%; Average loss: 3.9769
# Iteration: 298; Percent complete: 7.4%; Average loss: 4.0632
# Iteration: 299; Percent complete: 7.5%; Average loss: 4.1545
# Iteration: 300; Percent complete: 7.5%; Average loss: 3.9552
# Iteration: 301; Percent complete: 7.5%; Average loss: 3.7879
# Iteration: 302; Percent complete: 7.5%; Average loss: 3.8628
# Iteration: 303; Percent complete: 7.6%; Average loss: 3.8436
# Iteration: 304; Percent complete: 7.6%; Average loss: 3.8141
# Iteration: 305; Percent complete: 7.6%; Average loss: 4.2534
# Iteration: 306; Percent complete: 7.6%; Average loss: 3.8386
# Iteration: 307; Percent complete: 7.7%; Average loss: 3.8159
# Iteration: 308; Percent complete: 7.7%; Average loss: 4.1198
# Iteration: 309; Percent complete: 7.7%; Average loss: 3.8779
# Iteration: 310; Percent complete: 7.8%; Average loss: 3.7513
# Iteration: 311; Percent complete: 7.8%; Average loss: 4.0987
# Iteration: 312; Percent complete: 7.8%; Average loss: 4.1370
# Iteration: 313; Percent complete: 7.8%; Average loss: 3.6443
# Iteration: 314; Percent complete: 7.8%; Average loss: 4.0359
# Iteration: 315; Percent complete: 7.9%; Average loss: 4.0438
# Iteration: 316; Percent complete: 7.9%; Average loss: 3.8579
# Iteration: 317; Percent complete: 7.9%; Average loss: 4.0442
# Iteration: 318; Percent complete: 8.0%; Average loss: 3.9034
# Iteration: 319; Percent complete: 8.0%; Average loss: 3.9834
# Iteration: 320; Percent complete: 8.0%; Average loss: 3.8909
# Iteration: 321; Percent complete: 8.0%; Average loss: 3.8127
# Iteration: 322; Percent complete: 8.1%; Average loss: 3.9890
# Iteration: 323; Percent complete: 8.1%; Average loss: 3.7129
# Iteration: 324; Percent complete: 8.1%; Average loss: 3.9449
# Iteration: 325; Percent complete: 8.1%; Average loss: 3.8113
# Iteration: 326; Percent complete: 8.2%; Average loss: 4.0072
# Iteration: 327; Percent complete: 8.2%; Average loss: 3.7603
# Iteration: 328; Percent complete: 8.2%; Average loss: 3.9227
# Iteration: 329; Percent complete: 8.2%; Average loss: 3.5561
# Iteration: 330; Percent complete: 8.2%; Average loss: 3.8251
# Iteration: 331; Percent complete: 8.3%; Average loss: 3.9974
# Iteration: 332; Percent complete: 8.3%; Average loss: 3.9555
# Iteration: 333; Percent complete: 8.3%; Average loss: 4.0658
# Iteration: 334; Percent complete: 8.3%; Average loss: 3.7962
# Iteration: 335; Percent complete: 8.4%; Average loss: 3.9291
# Iteration: 336; Percent complete: 8.4%; Average loss: 4.1065
# Iteration: 337; Percent complete: 8.4%; Average loss: 3.8423
# Iteration: 338; Percent complete: 8.5%; Average loss: 3.8235
# Iteration: 339; Percent complete: 8.5%; Average loss: 4.0735
# Iteration: 340; Percent complete: 8.5%; Average loss: 4.0040
# Iteration: 341; Percent complete: 8.5%; Average loss: 3.9722
# Iteration: 342; Percent complete: 8.6%; Average loss: 3.8875
# Iteration: 343; Percent complete: 8.6%; Average loss: 4.0637
# Iteration: 344; Percent complete: 8.6%; Average loss: 3.7845
# Iteration: 345; Percent complete: 8.6%; Average loss: 3.8542
# Iteration: 346; Percent complete: 8.6%; Average loss: 3.9603
# Iteration: 347; Percent complete: 8.7%; Average loss: 3.8550
# Iteration: 348; Percent complete: 8.7%; Average loss: 4.0815
# Iteration: 349; Percent complete: 8.7%; Average loss: 3.9104
# Iteration: 350; Percent complete: 8.8%; Average loss: 3.9498
# Iteration: 351; Percent complete: 8.8%; Average loss: 3.9916
# Iteration: 352; Percent complete: 8.8%; Average loss: 4.0752
# Iteration: 353; Percent complete: 8.8%; Average loss: 3.7566
# Iteration: 354; Percent complete: 8.8%; Average loss: 4.0683
# Iteration: 355; Percent complete: 8.9%; Average loss: 3.6129
# Iteration: 356; Percent complete: 8.9%; Average loss: 3.9609
# Iteration: 357; Percent complete: 8.9%; Average loss: 3.8650
# Iteration: 358; Percent complete: 8.9%; Average loss: 3.9987
# Iteration: 359; Percent complete: 9.0%; Average loss: 3.9069
# Iteration: 360; Percent complete: 9.0%; Average loss: 3.8033
# Iteration: 361; Percent complete: 9.0%; Average loss: 3.8435
# Iteration: 362; Percent complete: 9.0%; Average loss: 3.9933
# Iteration: 363; Percent complete: 9.1%; Average loss: 3.8387
# Iteration: 364; Percent complete: 9.1%; Average loss: 3.7637
# Iteration: 365; Percent complete: 9.1%; Average loss: 3.9726
# Iteration: 366; Percent complete: 9.2%; Average loss: 3.9195
# Iteration: 367; Percent complete: 9.2%; Average loss: 3.5285
# Iteration: 368; Percent complete: 9.2%; Average loss: 3.6054
# Iteration: 369; Percent complete: 9.2%; Average loss: 3.9301
# Iteration: 370; Percent complete: 9.2%; Average loss: 3.7389
# Iteration: 371; Percent complete: 9.3%; Average loss: 4.0892
# Iteration: 372; Percent complete: 9.3%; Average loss: 4.0232
# Iteration: 373; Percent complete: 9.3%; Average loss: 3.7775
# Iteration: 374; Percent complete: 9.3%; Average loss: 3.7681
# Iteration: 375; Percent complete: 9.4%; Average loss: 3.9590
# Iteration: 376; Percent complete: 9.4%; Average loss: 3.6645
# Iteration: 377; Percent complete: 9.4%; Average loss: 4.0475
# Iteration: 378; Percent complete: 9.4%; Average loss: 3.9016
# Iteration: 379; Percent complete: 9.5%; Average loss: 3.8163
# Iteration: 380; Percent complete: 9.5%; Average loss: 3.8157
# Iteration: 381; Percent complete: 9.5%; Average loss: 3.7342
# Iteration: 382; Percent complete: 9.6%; Average loss: 3.7923
# Iteration: 383; Percent complete: 9.6%; Average loss: 3.8464
# Iteration: 384; Percent complete: 9.6%; Average loss: 3.9688
# Iteration: 385; Percent complete: 9.6%; Average loss: 3.8567
# Iteration: 386; Percent complete: 9.7%; Average loss: 3.7630
# Iteration: 387; Percent complete: 9.7%; Average loss: 3.9341
# Iteration: 388; Percent complete: 9.7%; Average loss: 3.7793
# Iteration: 389; Percent complete: 9.7%; Average loss: 3.5044
# Iteration: 390; Percent complete: 9.8%; Average loss: 3.7966
# Iteration: 391; Percent complete: 9.8%; Average loss: 3.5920
# Iteration: 392; Percent complete: 9.8%; Average loss: 3.8573
# Iteration: 393; Percent complete: 9.8%; Average loss: 3.7841
# Iteration: 394; Percent complete: 9.8%; Average loss: 3.8579
# Iteration: 395; Percent complete: 9.9%; Average loss: 3.7048
# Iteration: 396; Percent complete: 9.9%; Average loss: 3.8454
# Iteration: 397; Percent complete: 9.9%; Average loss: 3.6124
# Iteration: 398; Percent complete: 10.0%; Average loss: 3.9510
# Iteration: 399; Percent complete: 10.0%; Average loss: 3.7709
# Iteration: 400; Percent complete: 10.0%; Average loss: 3.7851
# Iteration: 401; Percent complete: 10.0%; Average loss: 3.8232
# Iteration: 402; Percent complete: 10.1%; Average loss: 3.7414
# Iteration: 403; Percent complete: 10.1%; Average loss: 3.9891
# Iteration: 404; Percent complete: 10.1%; Average loss: 3.9103
# Iteration: 405; Percent complete: 10.1%; Average loss: 3.4413
# Iteration: 406; Percent complete: 10.2%; Average loss: 3.5871
# Iteration: 407; Percent complete: 10.2%; Average loss: 3.6201
# Iteration: 408; Percent complete: 10.2%; Average loss: 3.8287
# Iteration: 409; Percent complete: 10.2%; Average loss: 3.9044
# Iteration: 410; Percent complete: 10.2%; Average loss: 3.5639
# Iteration: 411; Percent complete: 10.3%; Average loss: 3.7204
# Iteration: 412; Percent complete: 10.3%; Average loss: 3.7580
# Iteration: 413; Percent complete: 10.3%; Average loss: 4.0243
# Iteration: 414; Percent complete: 10.3%; Average loss: 3.7199
# Iteration: 415; Percent complete: 10.4%; Average loss: 3.7511
# Iteration: 416; Percent complete: 10.4%; Average loss: 3.8849
# Iteration: 417; Percent complete: 10.4%; Average loss: 3.9922
# Iteration: 418; Percent complete: 10.4%; Average loss: 4.2125
# Iteration: 419; Percent complete: 10.5%; Average loss: 3.4965
# Iteration: 420; Percent complete: 10.5%; Average loss: 3.8271
# Iteration: 421; Percent complete: 10.5%; Average loss: 3.7125
# Iteration: 422; Percent complete: 10.5%; Average loss: 3.7510
# Iteration: 423; Percent complete: 10.6%; Average loss: 3.8372
# Iteration: 424; Percent complete: 10.6%; Average loss: 3.4899
# Iteration: 425; Percent complete: 10.6%; Average loss: 3.8507
# Iteration: 426; Percent complete: 10.7%; Average loss: 3.7892
# Iteration: 427; Percent complete: 10.7%; Average loss: 3.4215
# Iteration: 428; Percent complete: 10.7%; Average loss: 3.7059
# Iteration: 429; Percent complete: 10.7%; Average loss: 3.7830
# Iteration: 430; Percent complete: 10.8%; Average loss: 3.8235
# Iteration: 431; Percent complete: 10.8%; Average loss: 3.7523
# Iteration: 432; Percent complete: 10.8%; Average loss: 4.2203
# Iteration: 433; Percent complete: 10.8%; Average loss: 3.5560
# Iteration: 434; Percent complete: 10.8%; Average loss: 3.4763
# Iteration: 435; Percent complete: 10.9%; Average loss: 3.5954
# Iteration: 436; Percent complete: 10.9%; Average loss: 3.6826
# Iteration: 437; Percent complete: 10.9%; Average loss: 3.8674
# Iteration: 438; Percent complete: 10.9%; Average loss: 3.8013
# Iteration: 439; Percent complete: 11.0%; Average loss: 3.9643
# Iteration: 440; Percent complete: 11.0%; Average loss: 3.5336
# Iteration: 441; Percent complete: 11.0%; Average loss: 3.5542
# Iteration: 442; Percent complete: 11.1%; Average loss: 3.6930
# Iteration: 443; Percent complete: 11.1%; Average loss: 3.8937
# Iteration: 444; Percent complete: 11.1%; Average loss: 3.9090
# Iteration: 445; Percent complete: 11.1%; Average loss: 4.0949
# Iteration: 446; Percent complete: 11.2%; Average loss: 3.6261
# Iteration: 447; Percent complete: 11.2%; Average loss: 3.9105
# Iteration: 448; Percent complete: 11.2%; Average loss: 3.7539
# Iteration: 449; Percent complete: 11.2%; Average loss: 3.6543
# Iteration: 450; Percent complete: 11.2%; Average loss: 3.8612
# Iteration: 451; Percent complete: 11.3%; Average loss: 3.6769
# Iteration: 452; Percent complete: 11.3%; Average loss: 3.8086
# Iteration: 453; Percent complete: 11.3%; Average loss: 3.6813
# Iteration: 454; Percent complete: 11.3%; Average loss: 3.8255
# Iteration: 455; Percent complete: 11.4%; Average loss: 3.7272
# Iteration: 456; Percent complete: 11.4%; Average loss: 3.6147
# Iteration: 457; Percent complete: 11.4%; Average loss: 3.7434
# Iteration: 458; Percent complete: 11.5%; Average loss: 3.7238
# Iteration: 459; Percent complete: 11.5%; Average loss: 3.8367
# Iteration: 460; Percent complete: 11.5%; Average loss: 3.6049
# Iteration: 461; Percent complete: 11.5%; Average loss: 3.7741
# Iteration: 462; Percent complete: 11.6%; Average loss: 3.9318
# Iteration: 463; Percent complete: 11.6%; Average loss: 3.9225
# Iteration: 464; Percent complete: 11.6%; Average loss: 3.6972
# Iteration: 465; Percent complete: 11.6%; Average loss: 3.8606
# Iteration: 466; Percent complete: 11.7%; Average loss: 3.8788
# Iteration: 467; Percent complete: 11.7%; Average loss: 3.7420
# Iteration: 468; Percent complete: 11.7%; Average loss: 3.6570
# Iteration: 469; Percent complete: 11.7%; Average loss: 3.7123
# Iteration: 470; Percent complete: 11.8%; Average loss: 3.4927
# Iteration: 471; Percent complete: 11.8%; Average loss: 3.6719
# Iteration: 472; Percent complete: 11.8%; Average loss: 3.7025
# Iteration: 473; Percent complete: 11.8%; Average loss: 3.9312
# Iteration: 474; Percent complete: 11.8%; Average loss: 3.6338
# Iteration: 475; Percent complete: 11.9%; Average loss: 3.6902
# Iteration: 476; Percent complete: 11.9%; Average loss: 3.5603
# Iteration: 477; Percent complete: 11.9%; Average loss: 3.5490
# Iteration: 478; Percent complete: 11.9%; Average loss: 4.0058
# Iteration: 479; Percent complete: 12.0%; Average loss: 3.8494
# Iteration: 480; Percent complete: 12.0%; Average loss: 3.7671
# Iteration: 481; Percent complete: 12.0%; Average loss: 3.9157
# Iteration: 482; Percent complete: 12.0%; Average loss: 3.6985
# Iteration: 483; Percent complete: 12.1%; Average loss: 3.7063
# Iteration: 484; Percent complete: 12.1%; Average loss: 3.6690
# Iteration: 485; Percent complete: 12.1%; Average loss: 3.7325
# Iteration: 486; Percent complete: 12.2%; Average loss: 3.7402
# Iteration: 487; Percent complete: 12.2%; Average loss: 3.6502
# Iteration: 488; Percent complete: 12.2%; Average loss: 3.9173
# Iteration: 489; Percent complete: 12.2%; Average loss: 3.8988
# Iteration: 490; Percent complete: 12.2%; Average loss: 3.6896
# Iteration: 491; Percent complete: 12.3%; Average loss: 4.0871
# Iteration: 492; Percent complete: 12.3%; Average loss: 3.6103
# Iteration: 493; Percent complete: 12.3%; Average loss: 3.8301
# Iteration: 494; Percent complete: 12.3%; Average loss: 3.6824
# Iteration: 495; Percent complete: 12.4%; Average loss: 3.7360
# Iteration: 496; Percent complete: 12.4%; Average loss: 3.7914
# Iteration: 497; Percent complete: 12.4%; Average loss: 3.7469
# Iteration: 498; Percent complete: 12.4%; Average loss: 3.7139
# Iteration: 499; Percent complete: 12.5%; Average loss: 3.7234
# Iteration: 500; Percent complete: 12.5%; Average loss: 3.8939
# Iteration: 501; Percent complete: 12.5%; Average loss: 3.7838
# Iteration: 502; Percent complete: 12.6%; Average loss: 3.7255
# Iteration: 503; Percent complete: 12.6%; Average loss: 3.6774
# Iteration: 504; Percent complete: 12.6%; Average loss: 3.6217
# Iteration: 505; Percent complete: 12.6%; Average loss: 3.7641
# Iteration: 506; Percent complete: 12.7%; Average loss: 3.8204
# Iteration: 507; Percent complete: 12.7%; Average loss: 3.8106
# Iteration: 508; Percent complete: 12.7%; Average loss: 3.5218
# Iteration: 509; Percent complete: 12.7%; Average loss: 3.6772
# Iteration: 510; Percent complete: 12.8%; Average loss: 3.5560
# Iteration: 511; Percent complete: 12.8%; Average loss: 3.7008
# Iteration: 512; Percent complete: 12.8%; Average loss: 3.5303
# Iteration: 513; Percent complete: 12.8%; Average loss: 3.4102
# Iteration: 514; Percent complete: 12.8%; Average loss: 3.8222
# Iteration: 515; Percent complete: 12.9%; Average loss: 3.6829
# Iteration: 516; Percent complete: 12.9%; Average loss: 3.6584
# Iteration: 517; Percent complete: 12.9%; Average loss: 3.7131
# Iteration: 518; Percent complete: 13.0%; Average loss: 3.6376
# Iteration: 519; Percent complete: 13.0%; Average loss: 3.5305
# Iteration: 520; Percent complete: 13.0%; Average loss: 3.8296
# Iteration: 521; Percent complete: 13.0%; Average loss: 3.6251
# Iteration: 522; Percent complete: 13.1%; Average loss: 3.7496
# Iteration: 523; Percent complete: 13.1%; Average loss: 3.6207
# Iteration: 524; Percent complete: 13.1%; Average loss: 4.0075
# Iteration: 525; Percent complete: 13.1%; Average loss: 3.6394
# Iteration: 526; Percent complete: 13.2%; Average loss: 4.3034
# Iteration: 527; Percent complete: 13.2%; Average loss: 3.9350
# Iteration: 528; Percent complete: 13.2%; Average loss: 4.0209
# Iteration: 529; Percent complete: 13.2%; Average loss: 3.6051
# Iteration: 530; Percent complete: 13.2%; Average loss: 3.5403
# Iteration: 531; Percent complete: 13.3%; Average loss: 3.5142
# Iteration: 532; Percent complete: 13.3%; Average loss: 3.6930
# Iteration: 533; Percent complete: 13.3%; Average loss: 3.9055
# Iteration: 534; Percent complete: 13.4%; Average loss: 3.4782
# Iteration: 535; Percent complete: 13.4%; Average loss: 3.7073
# Iteration: 536; Percent complete: 13.4%; Average loss: 3.5799
# Iteration: 537; Percent complete: 13.4%; Average loss: 3.8111
# Iteration: 538; Percent complete: 13.5%; Average loss: 3.5329
# Iteration: 539; Percent complete: 13.5%; Average loss: 3.4673
# Iteration: 540; Percent complete: 13.5%; Average loss: 3.6094
# Iteration: 541; Percent complete: 13.5%; Average loss: 3.7299
# Iteration: 542; Percent complete: 13.6%; Average loss: 3.6093
# Iteration: 543; Percent complete: 13.6%; Average loss: 3.6304
# Iteration: 544; Percent complete: 13.6%; Average loss: 3.8200
# Iteration: 545; Percent complete: 13.6%; Average loss: 3.8347
# Iteration: 546; Percent complete: 13.7%; Average loss: 3.5149
# Iteration: 547; Percent complete: 13.7%; Average loss: 3.8692
# Iteration: 548; Percent complete: 13.7%; Average loss: 3.9620
# Iteration: 549; Percent complete: 13.7%; Average loss: 3.6479
# Iteration: 550; Percent complete: 13.8%; Average loss: 3.8609
# Iteration: 551; Percent complete: 13.8%; Average loss: 3.6817
# Iteration: 552; Percent complete: 13.8%; Average loss: 3.8007
# Iteration: 553; Percent complete: 13.8%; Average loss: 3.9143
# Iteration: 554; Percent complete: 13.9%; Average loss: 3.5126
# Iteration: 555; Percent complete: 13.9%; Average loss: 3.7769
# Iteration: 556; Percent complete: 13.9%; Average loss: 3.4540
# Iteration: 557; Percent complete: 13.9%; Average loss: 3.5049
# Iteration: 558; Percent complete: 14.0%; Average loss: 3.6977
# Iteration: 559; Percent complete: 14.0%; Average loss: 3.7005
# Iteration: 560; Percent complete: 14.0%; Average loss: 3.6390
# Iteration: 561; Percent complete: 14.0%; Average loss: 3.5897
# Iteration: 562; Percent complete: 14.1%; Average loss: 3.5573
# Iteration: 563; Percent complete: 14.1%; Average loss: 3.5971
# Iteration: 564; Percent complete: 14.1%; Average loss: 3.4823
# Iteration: 565; Percent complete: 14.1%; Average loss: 3.7737
# Iteration: 566; Percent complete: 14.1%; Average loss: 3.7617
# Iteration: 567; Percent complete: 14.2%; Average loss: 3.7065
# Iteration: 568; Percent complete: 14.2%; Average loss: 3.6040
# Iteration: 569; Percent complete: 14.2%; Average loss: 3.8000
# Iteration: 570; Percent complete: 14.2%; Average loss: 3.6637
# Iteration: 571; Percent complete: 14.3%; Average loss: 3.8171
# Iteration: 572; Percent complete: 14.3%; Average loss: 3.3316
# Iteration: 573; Percent complete: 14.3%; Average loss: 3.6945
# Iteration: 574; Percent complete: 14.3%; Average loss: 3.8373
# Iteration: 575; Percent complete: 14.4%; Average loss: 3.5654
# Iteration: 576; Percent complete: 14.4%; Average loss: 3.6277
# Iteration: 577; Percent complete: 14.4%; Average loss: 3.6161
# Iteration: 578; Percent complete: 14.4%; Average loss: 3.6171
# Iteration: 579; Percent complete: 14.5%; Average loss: 3.7360
# Iteration: 580; Percent complete: 14.5%; Average loss: 3.8119
# Iteration: 581; Percent complete: 14.5%; Average loss: 3.3672
# Iteration: 582; Percent complete: 14.5%; Average loss: 3.7155
# Iteration: 583; Percent complete: 14.6%; Average loss: 3.7348
# Iteration: 584; Percent complete: 14.6%; Average loss: 3.7858
# Iteration: 585; Percent complete: 14.6%; Average loss: 3.7419
# Iteration: 586; Percent complete: 14.6%; Average loss: 3.4337
# Iteration: 587; Percent complete: 14.7%; Average loss: 3.5788
# Iteration: 588; Percent complete: 14.7%; Average loss: 3.8666
# Iteration: 589; Percent complete: 14.7%; Average loss: 3.7580
# Iteration: 590; Percent complete: 14.8%; Average loss: 3.7484
# Iteration: 591; Percent complete: 14.8%; Average loss: 3.5691
# Iteration: 592; Percent complete: 14.8%; Average loss: 3.7816
# Iteration: 593; Percent complete: 14.8%; Average loss: 3.5563
# Iteration: 594; Percent complete: 14.8%; Average loss: 3.7301
# Iteration: 595; Percent complete: 14.9%; Average loss: 3.5175
# Iteration: 596; Percent complete: 14.9%; Average loss: 3.6746
# Iteration: 597; Percent complete: 14.9%; Average loss: 3.3273
# Iteration: 598; Percent complete: 14.9%; Average loss: 3.6728
# Iteration: 599; Percent complete: 15.0%; Average loss: 3.8502
# Iteration: 600; Percent complete: 15.0%; Average loss: 3.6846
# Iteration: 601; Percent complete: 15.0%; Average loss: 3.6287
# Iteration: 602; Percent complete: 15.0%; Average loss: 3.6300
# Iteration: 603; Percent complete: 15.1%; Average loss: 3.6644
# Iteration: 604; Percent complete: 15.1%; Average loss: 3.6527
# Iteration: 605; Percent complete: 15.1%; Average loss: 3.5739
# Iteration: 606; Percent complete: 15.2%; Average loss: 3.6331
# Iteration: 607; Percent complete: 15.2%; Average loss: 3.5182
# Iteration: 608; Percent complete: 15.2%; Average loss: 3.5928
# Iteration: 609; Percent complete: 15.2%; Average loss: 3.6210
# Iteration: 610; Percent complete: 15.2%; Average loss: 3.4393
# Iteration: 611; Percent complete: 15.3%; Average loss: 3.7053
# Iteration: 612; Percent complete: 15.3%; Average loss: 3.5403
# Iteration: 613; Percent complete: 15.3%; Average loss: 3.6050
# Iteration: 614; Percent complete: 15.3%; Average loss: 3.8172
# Iteration: 615; Percent complete: 15.4%; Average loss: 3.3198
# Iteration: 616; Percent complete: 15.4%; Average loss: 3.5771
# Iteration: 617; Percent complete: 15.4%; Average loss: 3.5264
# Iteration: 618; Percent complete: 15.4%; Average loss: 3.4968
# Iteration: 619; Percent complete: 15.5%; Average loss: 3.5518
# Iteration: 620; Percent complete: 15.5%; Average loss: 3.8253
# Iteration: 621; Percent complete: 15.5%; Average loss: 3.6296
# Iteration: 622; Percent complete: 15.6%; Average loss: 3.5248
# Iteration: 623; Percent complete: 15.6%; Average loss: 3.4196
# Iteration: 624; Percent complete: 15.6%; Average loss: 3.3983
# Iteration: 625; Percent complete: 15.6%; Average loss: 3.6691
# Iteration: 626; Percent complete: 15.7%; Average loss: 3.2862
# Iteration: 627; Percent complete: 15.7%; Average loss: 3.4004
# Iteration: 628; Percent complete: 15.7%; Average loss: 3.8049
# Iteration: 629; Percent complete: 15.7%; Average loss: 4.0521
# Iteration: 630; Percent complete: 15.8%; Average loss: 3.3763
# Iteration: 631; Percent complete: 15.8%; Average loss: 3.7172
# Iteration: 632; Percent complete: 15.8%; Average loss: 3.7017
# Iteration: 633; Percent complete: 15.8%; Average loss: 3.5810
# Iteration: 634; Percent complete: 15.8%; Average loss: 3.4021
# Iteration: 635; Percent complete: 15.9%; Average loss: 3.8110
# Iteration: 636; Percent complete: 15.9%; Average loss: 3.5402
# Iteration: 637; Percent complete: 15.9%; Average loss: 3.6339
# Iteration: 638; Percent complete: 16.0%; Average loss: 3.8404
# Iteration: 639; Percent complete: 16.0%; Average loss: 3.8025
# Iteration: 640; Percent complete: 16.0%; Average loss: 3.5411
# Iteration: 641; Percent complete: 16.0%; Average loss: 3.6137
# Iteration: 642; Percent complete: 16.1%; Average loss: 3.5200
# Iteration: 643; Percent complete: 16.1%; Average loss: 3.6212
# Iteration: 644; Percent complete: 16.1%; Average loss: 3.5399
# Iteration: 645; Percent complete: 16.1%; Average loss: 3.7205
# Iteration: 646; Percent complete: 16.2%; Average loss: 3.7031
# Iteration: 647; Percent complete: 16.2%; Average loss: 3.5722
# Iteration: 648; Percent complete: 16.2%; Average loss: 3.5384
# Iteration: 649; Percent complete: 16.2%; Average loss: 3.8213
# Iteration: 650; Percent complete: 16.2%; Average loss: 3.9767
# Iteration: 651; Percent complete: 16.3%; Average loss: 3.8420
# Iteration: 652; Percent complete: 16.3%; Average loss: 3.7509
# Iteration: 653; Percent complete: 16.3%; Average loss: 3.8487
# Iteration: 654; Percent complete: 16.4%; Average loss: 3.8024
# Iteration: 655; Percent complete: 16.4%; Average loss: 3.7684
# Iteration: 656; Percent complete: 16.4%; Average loss: 3.4874
# Iteration: 657; Percent complete: 16.4%; Average loss: 3.5424
# Iteration: 658; Percent complete: 16.4%; Average loss: 3.4953
# Iteration: 659; Percent complete: 16.5%; Average loss: 3.5799
# Iteration: 660; Percent complete: 16.5%; Average loss: 3.6200
# Iteration: 661; Percent complete: 16.5%; Average loss: 3.7679
# Iteration: 662; Percent complete: 16.6%; Average loss: 3.3260
# Iteration: 663; Percent complete: 16.6%; Average loss: 3.6503
# Iteration: 664; Percent complete: 16.6%; Average loss: 3.6844
# Iteration: 665; Percent complete: 16.6%; Average loss: 3.8743
# Iteration: 666; Percent complete: 16.7%; Average loss: 3.4250
# Iteration: 667; Percent complete: 16.7%; Average loss: 3.7113
# Iteration: 668; Percent complete: 16.7%; Average loss: 3.7262
# Iteration: 669; Percent complete: 16.7%; Average loss: 3.4445
# Iteration: 670; Percent complete: 16.8%; Average loss: 3.5733
# Iteration: 671; Percent complete: 16.8%; Average loss: 3.4804
# Iteration: 672; Percent complete: 16.8%; Average loss: 3.2831
# Iteration: 673; Percent complete: 16.8%; Average loss: 3.3592
# Iteration: 674; Percent complete: 16.9%; Average loss: 3.5167
# Iteration: 675; Percent complete: 16.9%; Average loss: 3.7330
# Iteration: 676; Percent complete: 16.9%; Average loss: 3.4031
# Iteration: 677; Percent complete: 16.9%; Average loss: 3.5588
# Iteration: 678; Percent complete: 17.0%; Average loss: 3.5591
# Iteration: 679; Percent complete: 17.0%; Average loss: 3.7086
# Iteration: 680; Percent complete: 17.0%; Average loss: 3.7656
# Iteration: 681; Percent complete: 17.0%; Average loss: 3.4708
# Iteration: 682; Percent complete: 17.1%; Average loss: 3.6286
# Iteration: 683; Percent complete: 17.1%; Average loss: 3.5841
# Iteration: 684; Percent complete: 17.1%; Average loss: 3.4624
# Iteration: 685; Percent complete: 17.1%; Average loss: 3.2183
# Iteration: 686; Percent complete: 17.2%; Average loss: 3.6159
# Iteration: 687; Percent complete: 17.2%; Average loss: 3.8297
# Iteration: 688; Percent complete: 17.2%; Average loss: 3.7134
# Iteration: 689; Percent complete: 17.2%; Average loss: 3.5545
# Iteration: 690; Percent complete: 17.2%; Average loss: 3.6111
# Iteration: 691; Percent complete: 17.3%; Average loss: 3.5580
# Iteration: 692; Percent complete: 17.3%; Average loss: 3.4908
# Iteration: 693; Percent complete: 17.3%; Average loss: 3.3769
# Iteration: 694; Percent complete: 17.3%; Average loss: 3.7794
# Iteration: 695; Percent complete: 17.4%; Average loss: 3.8187
# Iteration: 696; Percent complete: 17.4%; Average loss: 3.6028
# Iteration: 697; Percent complete: 17.4%; Average loss: 3.6382
# Iteration: 698; Percent complete: 17.4%; Average loss: 3.3952
# Iteration: 699; Percent complete: 17.5%; Average loss: 3.4057
# Iteration: 700; Percent complete: 17.5%; Average loss: 3.6873
# Iteration: 701; Percent complete: 17.5%; Average loss: 3.3664
# Iteration: 702; Percent complete: 17.5%; Average loss: 3.8495
# Iteration: 703; Percent complete: 17.6%; Average loss: 3.7082
# Iteration: 704; Percent complete: 17.6%; Average loss: 3.4964
# Iteration: 705; Percent complete: 17.6%; Average loss: 3.6979
# Iteration: 706; Percent complete: 17.6%; Average loss: 3.5696
# Iteration: 707; Percent complete: 17.7%; Average loss: 3.4816
# Iteration: 708; Percent complete: 17.7%; Average loss: 3.4703
# Iteration: 709; Percent complete: 17.7%; Average loss: 3.8074
# Iteration: 710; Percent complete: 17.8%; Average loss: 3.8144
# Iteration: 711; Percent complete: 17.8%; Average loss: 3.6423
# Iteration: 712; Percent complete: 17.8%; Average loss: 3.6767
# Iteration: 713; Percent complete: 17.8%; Average loss: 3.6401
# Iteration: 714; Percent complete: 17.8%; Average loss: 3.5690
# Iteration: 715; Percent complete: 17.9%; Average loss: 3.8028
# Iteration: 716; Percent complete: 17.9%; Average loss: 3.6279
# Iteration: 717; Percent complete: 17.9%; Average loss: 3.6506
# Iteration: 718; Percent complete: 17.9%; Average loss: 3.4345
# Iteration: 719; Percent complete: 18.0%; Average loss: 3.7715
# Iteration: 720; Percent complete: 18.0%; Average loss: 3.2937
# Iteration: 721; Percent complete: 18.0%; Average loss: 3.5108
# Iteration: 722; Percent complete: 18.1%; Average loss: 3.5907
# Iteration: 723; Percent complete: 18.1%; Average loss: 3.3511
# Iteration: 724; Percent complete: 18.1%; Average loss: 3.6082
# Iteration: 725; Percent complete: 18.1%; Average loss: 3.7257
# Iteration: 726; Percent complete: 18.1%; Average loss: 3.4455
# Iteration: 727; Percent complete: 18.2%; Average loss: 3.6169
# Iteration: 728; Percent complete: 18.2%; Average loss: 3.7308
# Iteration: 729; Percent complete: 18.2%; Average loss: 3.4596
# Iteration: 730; Percent complete: 18.2%; Average loss: 3.7639
# Iteration: 731; Percent complete: 18.3%; Average loss: 3.8224
# Iteration: 732; Percent complete: 18.3%; Average loss: 3.5263
# Iteration: 733; Percent complete: 18.3%; Average loss: 3.2412
# Iteration: 734; Percent complete: 18.4%; Average loss: 3.6980
# Iteration: 735; Percent complete: 18.4%; Average loss: 3.5070
# Iteration: 736; Percent complete: 18.4%; Average loss: 3.6865
# Iteration: 737; Percent complete: 18.4%; Average loss: 3.5961
# Iteration: 738; Percent complete: 18.4%; Average loss: 3.4286
# Iteration: 739; Percent complete: 18.5%; Average loss: 3.5592
# Iteration: 740; Percent complete: 18.5%; Average loss: 3.5464
# Iteration: 741; Percent complete: 18.5%; Average loss: 3.4321
# Iteration: 742; Percent complete: 18.6%; Average loss: 3.3965
# Iteration: 743; Percent complete: 18.6%; Average loss: 3.4929
# Iteration: 744; Percent complete: 18.6%; Average loss: 3.5506
# Iteration: 745; Percent complete: 18.6%; Average loss: 3.4112
# Iteration: 746; Percent complete: 18.6%; Average loss: 3.3939
# Iteration: 747; Percent complete: 18.7%; Average loss: 3.6423
# Iteration: 748; Percent complete: 18.7%; Average loss: 3.5730
# Iteration: 749; Percent complete: 18.7%; Average loss: 3.5943
# Iteration: 750; Percent complete: 18.8%; Average loss: 3.4443
# Iteration: 751; Percent complete: 18.8%; Average loss: 3.5583
# Iteration: 752; Percent complete: 18.8%; Average loss: 3.8136
# Iteration: 753; Percent complete: 18.8%; Average loss: 3.5489
# Iteration: 754; Percent complete: 18.9%; Average loss: 3.4807
# Iteration: 755; Percent complete: 18.9%; Average loss: 3.5888
# Iteration: 756; Percent complete: 18.9%; Average loss: 3.4219
# Iteration: 757; Percent complete: 18.9%; Average loss: 3.3744
# Iteration: 758; Percent complete: 18.9%; Average loss: 3.3728
# Iteration: 759; Percent complete: 19.0%; Average loss: 3.4882
# Iteration: 760; Percent complete: 19.0%; Average loss: 3.5815
# Iteration: 761; Percent complete: 19.0%; Average loss: 3.5795
# Iteration: 762; Percent complete: 19.1%; Average loss: 3.6201
# Iteration: 763; Percent complete: 19.1%; Average loss: 3.4559
# Iteration: 764; Percent complete: 19.1%; Average loss: 3.3461
# Iteration: 765; Percent complete: 19.1%; Average loss: 3.6037
# Iteration: 766; Percent complete: 19.1%; Average loss: 3.4166
# Iteration: 767; Percent complete: 19.2%; Average loss: 3.2940
# Iteration: 768; Percent complete: 19.2%; Average loss: 3.4863
# Iteration: 769; Percent complete: 19.2%; Average loss: 3.3414
# Iteration: 770; Percent complete: 19.2%; Average loss: 3.6078
# Iteration: 771; Percent complete: 19.3%; Average loss: 3.1968
# Iteration: 772; Percent complete: 19.3%; Average loss: 3.5817
# Iteration: 773; Percent complete: 19.3%; Average loss: 3.5369
# Iteration: 774; Percent complete: 19.4%; Average loss: 3.6241
# Iteration: 775; Percent complete: 19.4%; Average loss: 3.3787
# Iteration: 776; Percent complete: 19.4%; Average loss: 3.6219
# Iteration: 777; Percent complete: 19.4%; Average loss: 3.3850
# Iteration: 778; Percent complete: 19.4%; Average loss: 3.6949
# Iteration: 779; Percent complete: 19.5%; Average loss: 3.7614
# Iteration: 780; Percent complete: 19.5%; Average loss: 3.5314
# Iteration: 781; Percent complete: 19.5%; Average loss: 3.6490
# ...
# Iteration: 1997; Percent complete: 49.9%; Average loss: 3.1351
# Iteration: 1998; Percent complete: 50.0%; Average loss: 3.0554
# Iteration: 1999; Percent complete: 50.0%; Average loss: 3.3247
# Iteration: 2000; Percent complete: 50.0%; Average loss: 3.0657
# Iteration: 2001; Percent complete: 50.0%; Average loss: 3.0589
# Iteration: 2002; Percent complete: 50.0%; Average loss: 3.1341
# Iteration: 2003; Percent complete: 50.1%; Average loss: 2.9148
# Iteration: 2004; Percent complete: 50.1%; Average loss: 3.4361
# Iteration: 2005; Percent complete: 50.1%; Average loss: 3.0356
# Iteration: 2006; Percent complete: 50.1%; Average loss: 2.7816
# Iteration: 2007; Percent complete: 50.2%; Average loss: 3.3166
# Iteration: 2008; Percent complete: 50.2%; Average loss: 3.0494
# Iteration: 2009; Percent complete: 50.2%; Average loss: 3.1559
# Iteration: 2010; Percent complete: 50.2%; Average loss: 3.2422
# Iteration: 2011; Percent complete: 50.3%; Average loss: 2.9808
# Iteration: 2012; Percent complete: 50.3%; Average loss: 3.0263
# Iteration: 2013; Percent complete: 50.3%; Average loss: 2.7869
# Iteration: 2014; Percent complete: 50.3%; Average loss: 3.0487
# Iteration: 2015; Percent complete: 50.4%; Average loss: 3.3435
# Iteration: 2016; Percent complete: 50.4%; Average loss: 3.1106
# Iteration: 2017; Percent complete: 50.4%; Average loss: 3.1437
# Iteration: 2018; Percent complete: 50.4%; Average loss: 3.1910
# Iteration: 2019; Percent complete: 50.5%; Average loss: 3.0841
# Iteration: 2020; Percent complete: 50.5%; Average loss: 3.3627
# Iteration: 2021; Percent complete: 50.5%; Average loss: 3.2438
# Iteration: 2022; Percent complete: 50.5%; Average loss: 3.1296
# Iteration: 2023; Percent complete: 50.6%; Average loss: 3.1205
# Iteration: 2024; Percent complete: 50.6%; Average loss: 3.3145
# Iteration: 2025; Percent complete: 50.6%; Average loss: 3.2655
# Iteration: 2026; Percent complete: 50.6%; Average loss: 2.9954
# Iteration: 2027; Percent complete: 50.7%; Average loss: 2.9319
# Iteration: 2028; Percent complete: 50.7%; Average loss: 3.2817
# Iteration: 2029; Percent complete: 50.7%; Average loss: 3.3325
# Iteration: 2030; Percent complete: 50.7%; Average loss: 3.2120
# Iteration: 2031; Percent complete: 50.8%; Average loss: 3.2012
# Iteration: 2032; Percent complete: 50.8%; Average loss: 3.1961
# Iteration: 2033; Percent complete: 50.8%; Average loss: 3.1763
# Iteration: 2034; Percent complete: 50.8%; Average loss: 3.1894
# Iteration: 2035; Percent complete: 50.9%; Average loss: 2.9437
# Iteration: 2036; Percent complete: 50.9%; Average loss: 3.1863
# Iteration: 2037; Percent complete: 50.9%; Average loss: 3.3040
# Iteration: 2038; Percent complete: 50.9%; Average loss: 3.0671
# Iteration: 2039; Percent complete: 51.0%; Average loss: 3.2995
# Iteration: 2040; Percent complete: 51.0%; Average loss: 2.9962
# Iteration: 2041; Percent complete: 51.0%; Average loss: 3.0101
# Iteration: 2042; Percent complete: 51.0%; Average loss: 2.8677
# Iteration: 2043; Percent complete: 51.1%; Average loss: 3.2550
# Iteration: 2044; Percent complete: 51.1%; Average loss: 3.0167
# Iteration: 2045; Percent complete: 51.1%; Average loss: 3.0614
# Iteration: 2046; Percent complete: 51.1%; Average loss: 3.0892
# Iteration: 2047; Percent complete: 51.2%; Average loss: 3.1052
# Iteration: 2048; Percent complete: 51.2%; Average loss: 3.3820
# Iteration: 2049; Percent complete: 51.2%; Average loss: 3.0840
# Iteration: 2050; Percent complete: 51.2%; Average loss: 3.0778
# Iteration: 2051; Percent complete: 51.3%; Average loss: 2.8749
# Iteration: 2052; Percent complete: 51.3%; Average loss: 2.9509
# Iteration: 2053; Percent complete: 51.3%; Average loss: 3.1037
# Iteration: 2054; Percent complete: 51.3%; Average loss: 3.5747
# Iteration: 2055; Percent complete: 51.4%; Average loss: 3.1556
# Iteration: 2056; Percent complete: 51.4%; Average loss: 3.0904
# Iteration: 2057; Percent complete: 51.4%; Average loss: 3.1298
# Iteration: 2058; Percent complete: 51.4%; Average loss: 2.9397
# Iteration: 2059; Percent complete: 51.5%; Average loss: 2.9534
# Iteration: 2060; Percent complete: 51.5%; Average loss: 2.9810
# Iteration: 2061; Percent complete: 51.5%; Average loss: 3.4485
# Iteration: 2062; Percent complete: 51.5%; Average loss: 2.9928
# Iteration: 2063; Percent complete: 51.6%; Average loss: 2.9490
# Iteration: 2064; Percent complete: 51.6%; Average loss: 3.0575
# Iteration: 2065; Percent complete: 51.6%; Average loss: 3.0067
# Iteration: 2066; Percent complete: 51.6%; Average loss: 3.2932
# Iteration: 2067; Percent complete: 51.7%; Average loss: 2.9606
# Iteration: 2068; Percent complete: 51.7%; Average loss: 2.9892
# Iteration: 2069; Percent complete: 51.7%; Average loss: 3.2365
# Iteration: 2070; Percent complete: 51.7%; Average loss: 3.1234
# Iteration: 2071; Percent complete: 51.8%; Average loss: 3.1854
# Iteration: 2072; Percent complete: 51.8%; Average loss: 3.1202
# Iteration: 2073; Percent complete: 51.8%; Average loss: 2.8787
# Iteration: 2074; Percent complete: 51.8%; Average loss: 3.0602
# Iteration: 2075; Percent complete: 51.9%; Average loss: 3.2308
# Iteration: 2076; Percent complete: 51.9%; Average loss: 3.4100
# Iteration: 2077; Percent complete: 51.9%; Average loss: 3.0708
# Iteration: 2078; Percent complete: 51.9%; Average loss: 3.1488
# Iteration: 2079; Percent complete: 52.0%; Average loss: 3.3640
# Iteration: 2080; Percent complete: 52.0%; Average loss: 3.2139
# Iteration: 2081; Percent complete: 52.0%; Average loss: 2.8528
# Iteration: 2082; Percent complete: 52.0%; Average loss: 3.1867
# Iteration: 2083; Percent complete: 52.1%; Average loss: 3.0863
# Iteration: 2084; Percent complete: 52.1%; Average loss: 3.3290
# Iteration: 2085; Percent complete: 52.1%; Average loss: 3.3730
# Iteration: 2086; Percent complete: 52.1%; Average loss: 3.1479
# Iteration: 2087; Percent complete: 52.2%; Average loss: 3.1258
# Iteration: 2088; Percent complete: 52.2%; Average loss: 2.9221
# Iteration: 2089; Percent complete: 52.2%; Average loss: 3.1982
# Iteration: 2090; Percent complete: 52.2%; Average loss: 2.9405
# Iteration: 2091; Percent complete: 52.3%; Average loss: 3.4858
# Iteration: 2092; Percent complete: 52.3%; Average loss: 3.0850
# Iteration: 2093; Percent complete: 52.3%; Average loss: 2.7720
# Iteration: 2094; Percent complete: 52.3%; Average loss: 3.0642
# Iteration: 2095; Percent complete: 52.4%; Average loss: 3.0742
# Iteration: 2096; Percent complete: 52.4%; Average loss: 3.2524
# Iteration: 2097; Percent complete: 52.4%; Average loss: 3.1108
# Iteration: 2098; Percent complete: 52.4%; Average loss: 3.2836
# Iteration: 2099; Percent complete: 52.5%; Average loss: 3.2496
# Iteration: 2100; Percent complete: 52.5%; Average loss: 3.1950
# Iteration: 2101; Percent complete: 52.5%; Average loss: 3.1789
# Iteration: 2102; Percent complete: 52.5%; Average loss: 3.1862
# Iteration: 2103; Percent complete: 52.6%; Average loss: 3.3309
# Iteration: 2104; Percent complete: 52.6%; Average loss: 3.1216
# Iteration: 2105; Percent complete: 52.6%; Average loss: 3.3219
# Iteration: 2106; Percent complete: 52.6%; Average loss: 2.9101
# Iteration: 2107; Percent complete: 52.7%; Average loss: 3.3003
# Iteration: 2108; Percent complete: 52.7%; Average loss: 3.1308
# Iteration: 2109; Percent complete: 52.7%; Average loss: 3.0494
# Iteration: 2110; Percent complete: 52.8%; Average loss: 3.0315
# Iteration: 2111; Percent complete: 52.8%; Average loss: 2.9633
# Iteration: 2112; Percent complete: 52.8%; Average loss: 3.3394
# Iteration: 2113; Percent complete: 52.8%; Average loss: 3.0819
# Iteration: 2114; Percent complete: 52.8%; Average loss: 3.3422
# Iteration: 2115; Percent complete: 52.9%; Average loss: 3.1019
# Iteration: 2116; Percent complete: 52.9%; Average loss: 3.2004
# Iteration: 2117; Percent complete: 52.9%; Average loss: 2.9587
# Iteration: 2118; Percent complete: 52.9%; Average loss: 3.1854
# Iteration: 2119; Percent complete: 53.0%; Average loss: 3.1149
# Iteration: 2120; Percent complete: 53.0%; Average loss: 3.3342
# Iteration: 2121; Percent complete: 53.0%; Average loss: 3.2715
# Iteration: 2122; Percent complete: 53.0%; Average loss: 3.3765
# Iteration: 2123; Percent complete: 53.1%; Average loss: 3.0202
# Iteration: 2124; Percent complete: 53.1%; Average loss: 3.3185
# Iteration: 2125; Percent complete: 53.1%; Average loss: 3.3846
# Iteration: 2126; Percent complete: 53.1%; Average loss: 3.0711
# Iteration: 2127; Percent complete: 53.2%; Average loss: 3.2414
# Iteration: 2128; Percent complete: 53.2%; Average loss: 3.3188
# Iteration: 2129; Percent complete: 53.2%; Average loss: 3.0961
# Iteration: 2130; Percent complete: 53.2%; Average loss: 2.7835
# Iteration: 2131; Percent complete: 53.3%; Average loss: 3.1196
# Iteration: 2132; Percent complete: 53.3%; Average loss: 3.1764
# Iteration: 2133; Percent complete: 53.3%; Average loss: 3.1417
# Iteration: 2134; Percent complete: 53.3%; Average loss: 2.9984
# Iteration: 2135; Percent complete: 53.4%; Average loss: 3.1006
# Iteration: 2136; Percent complete: 53.4%; Average loss: 2.9535
# Iteration: 2137; Percent complete: 53.4%; Average loss: 3.2457
# Iteration: 2138; Percent complete: 53.4%; Average loss: 3.1830
# Iteration: 2139; Percent complete: 53.5%; Average loss: 3.1280
# Iteration: 2140; Percent complete: 53.5%; Average loss: 3.0274
# Iteration: 2141; Percent complete: 53.5%; Average loss: 2.9583
# Iteration: 2142; Percent complete: 53.5%; Average loss: 3.1918
# Iteration: 2143; Percent complete: 53.6%; Average loss: 2.9065
# Iteration: 2144; Percent complete: 53.6%; Average loss: 3.2978
# Iteration: 2145; Percent complete: 53.6%; Average loss: 2.9996
# Iteration: 2146; Percent complete: 53.6%; Average loss: 3.1342
# Iteration: 2147; Percent complete: 53.7%; Average loss: 2.9925
# Iteration: 2148; Percent complete: 53.7%; Average loss: 3.2796
# Iteration: 2149; Percent complete: 53.7%; Average loss: 2.8914
# Iteration: 2150; Percent complete: 53.8%; Average loss: 2.9251
# Iteration: 2151; Percent complete: 53.8%; Average loss: 2.9369
# Iteration: 2152; Percent complete: 53.8%; Average loss: 3.1727
# Iteration: 2153; Percent complete: 53.8%; Average loss: 3.0776
# Iteration: 2154; Percent complete: 53.8%; Average loss: 3.1755
# Iteration: 2155; Percent complete: 53.9%; Average loss: 3.1518
# Iteration: 2156; Percent complete: 53.9%; Average loss: 3.0666
# Iteration: 2157; Percent complete: 53.9%; Average loss: 3.0200
# Iteration: 2158; Percent complete: 53.9%; Average loss: 3.2268
# Iteration: 2159; Percent complete: 54.0%; Average loss: 2.9277
# Iteration: 2160; Percent complete: 54.0%; Average loss: 2.9130
# Iteration: 2161; Percent complete: 54.0%; Average loss: 3.3029
# Iteration: 2162; Percent complete: 54.0%; Average loss: 2.9071
# Iteration: 2163; Percent complete: 54.1%; Average loss: 3.1136
# Iteration: 2164; Percent complete: 54.1%; Average loss: 3.3792
# Iteration: 2165; Percent complete: 54.1%; Average loss: 3.2518
# Iteration: 2166; Percent complete: 54.1%; Average loss: 3.1576
# Iteration: 2167; Percent complete: 54.2%; Average loss: 3.0010
# Iteration: 2168; Percent complete: 54.2%; Average loss: 3.2940
# Iteration: 2169; Percent complete: 54.2%; Average loss: 3.0223
# Iteration: 2170; Percent complete: 54.2%; Average loss: 3.3332
# Iteration: 2171; Percent complete: 54.3%; Average loss: 2.9329
# Iteration: 2172; Percent complete: 54.3%; Average loss: 3.0429
# Iteration: 2173; Percent complete: 54.3%; Average loss: 2.8457
# Iteration: 2174; Percent complete: 54.4%; Average loss: 3.2789
# Iteration: 2175; Percent complete: 54.4%; Average loss: 3.2232
# Iteration: 2176; Percent complete: 54.4%; Average loss: 3.0274
# Iteration: 2177; Percent complete: 54.4%; Average loss: 3.1332
# Iteration: 2178; Percent complete: 54.4%; Average loss: 3.1817
# Iteration: 2179; Percent complete: 54.5%; Average loss: 3.0348
# Iteration: 2180; Percent complete: 54.5%; Average loss: 3.3008
# Iteration: 2181; Percent complete: 54.5%; Average loss: 3.0355
# Iteration: 2182; Percent complete: 54.5%; Average loss: 3.3466
# Iteration: 2183; Percent complete: 54.6%; Average loss: 3.1001
# Iteration: 2184; Percent complete: 54.6%; Average loss: 3.2320
# Iteration: 2185; Percent complete: 54.6%; Average loss: 3.1792
# Iteration: 2186; Percent complete: 54.6%; Average loss: 3.0773
# Iteration: 2187; Percent complete: 54.7%; Average loss: 3.1649
# Iteration: 2188; Percent complete: 54.7%; Average loss: 3.0121
# Iteration: 2189; Percent complete: 54.7%; Average loss: 2.9701
# Iteration: 2190; Percent complete: 54.8%; Average loss: 3.0820
# Iteration: 2191; Percent complete: 54.8%; Average loss: 3.1291
# Iteration: 2192; Percent complete: 54.8%; Average loss: 2.7458
# Iteration: 2193; Percent complete: 54.8%; Average loss: 3.2457
# Iteration: 2194; Percent complete: 54.9%; Average loss: 3.1342
# Iteration: 2195; Percent complete: 54.9%; Average loss: 3.0198
# Iteration: 2196; Percent complete: 54.9%; Average loss: 3.1763
# Iteration: 2197; Percent complete: 54.9%; Average loss: 3.0361
# Iteration: 2198; Percent complete: 54.9%; Average loss: 2.9858
# Iteration: 2199; Percent complete: 55.0%; Average loss: 3.2731
# Iteration: 2200; Percent complete: 55.0%; Average loss: 3.0110
# Iteration: 2201; Percent complete: 55.0%; Average loss: 3.0956
# Iteration: 2202; Percent complete: 55.0%; Average loss: 3.1002
# Iteration: 2203; Percent complete: 55.1%; Average loss: 3.1289
# Iteration: 2204; Percent complete: 55.1%; Average loss: 3.1692
# Iteration: 2205; Percent complete: 55.1%; Average loss: 3.2216
# Iteration: 2206; Percent complete: 55.1%; Average loss: 3.2983
# Iteration: 2207; Percent complete: 55.2%; Average loss: 3.1434
# Iteration: 2208; Percent complete: 55.2%; Average loss: 3.0247
# Iteration: 2209; Percent complete: 55.2%; Average loss: 2.7914
# Iteration: 2210; Percent complete: 55.2%; Average loss: 3.0559
# Iteration: 2211; Percent complete: 55.3%; Average loss: 3.1048
# Iteration: 2212; Percent complete: 55.3%; Average loss: 3.0716
# Iteration: 2213; Percent complete: 55.3%; Average loss: 2.9385
# Iteration: 2214; Percent complete: 55.4%; Average loss: 2.9740
# Iteration: 2215; Percent complete: 55.4%; Average loss: 3.1109
# Iteration: 2216; Percent complete: 55.4%; Average loss: 3.1054
# Iteration: 2217; Percent complete: 55.4%; Average loss: 3.0964
# Iteration: 2218; Percent complete: 55.5%; Average loss: 3.2950
# Iteration: 2219; Percent complete: 55.5%; Average loss: 3.0278
# Iteration: 2220; Percent complete: 55.5%; Average loss: 2.9763
# Iteration: 2221; Percent complete: 55.5%; Average loss: 3.1455
# Iteration: 2222; Percent complete: 55.5%; Average loss: 3.0698
# Iteration: 2223; Percent complete: 55.6%; Average loss: 3.0477
# Iteration: 2224; Percent complete: 55.6%; Average loss: 3.1980
# Iteration: 2225; Percent complete: 55.6%; Average loss: 3.3001
# Iteration: 2226; Percent complete: 55.6%; Average loss: 2.9936
# Iteration: 2227; Percent complete: 55.7%; Average loss: 2.9722
# Iteration: 2228; Percent complete: 55.7%; Average loss: 3.1580
# Iteration: 2229; Percent complete: 55.7%; Average loss: 2.9261
# Iteration: 2230; Percent complete: 55.8%; Average loss: 3.2139
# Iteration: 2231; Percent complete: 55.8%; Average loss: 3.0513
# Iteration: 2232; Percent complete: 55.8%; Average loss: 3.0773
# Iteration: 2233; Percent complete: 55.8%; Average loss: 2.9200
# Iteration: 2234; Percent complete: 55.9%; Average loss: 2.9464
# Iteration: 2235; Percent complete: 55.9%; Average loss: 2.9430
# Iteration: 2236; Percent complete: 55.9%; Average loss: 2.9279
# Iteration: 2237; Percent complete: 55.9%; Average loss: 3.0014
# Iteration: 2238; Percent complete: 56.0%; Average loss: 3.2414
# Iteration: 2239; Percent complete: 56.0%; Average loss: 2.9524
# Iteration: 2240; Percent complete: 56.0%; Average loss: 3.0059
# Iteration: 2241; Percent complete: 56.0%; Average loss: 3.0462
# Iteration: 2242; Percent complete: 56.0%; Average loss: 3.0455
# Iteration: 2243; Percent complete: 56.1%; Average loss: 3.3090
# Iteration: 2244; Percent complete: 56.1%; Average loss: 3.2319
# Iteration: 2245; Percent complete: 56.1%; Average loss: 3.2702
# Iteration: 2246; Percent complete: 56.1%; Average loss: 3.1759
# Iteration: 2247; Percent complete: 56.2%; Average loss: 3.3645
# Iteration: 2248; Percent complete: 56.2%; Average loss: 2.9646
# Iteration: 2249; Percent complete: 56.2%; Average loss: 3.3185

# %%
encoder.eval()
decoder.eval()

searcher = GreedySearchDecoder(encoder, decoder)

evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > hey bot
# Error: Encountered unknown word.
# > hey
# Bot: hey ! ! ! ! !
# > what are you doing
# Bot: i m doing a good man .
# > good man?
# Bot: good . . . . ?
# > who is good
# Bot: you know the police . . ?
# > i know the police
# Bot: you know the police ? ? ?
# > yes
# Bot: you re a good man . ? ?
# > youre a bad man
# Error: Encountered unknown word.
# > you re a bad man
# Bot: i m not a girl . . ?
# > you are a bad girl
# Bot: i m not sure . . ?
# > i am sure
# Bot: you re not . ? ? ?
# > i am
# Bot: you re not ! ! !
# > i am
# Bot: you re not ! ! !
# > you are
# Bot: i m not . . ? ?
# > i am
# Bot: you re not ! ! !
# > okay
# Bot: you re a good man . . ?
# > stop it
# Bot: i don t know . . ?
# > stop
# Bot: i m sorry . . . ?
# > not okay
# Bot: you re a good man . . ?
# > q
